# %% [markdown]
# #Data analysis
# 0.import the libraries
# 1.load the data
# 2.check the data and understand it.
# 3.properties of the data
# 4.explore the data
# 5. Visulize the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/indian_cities.csv')

# %%
df.head(n=-6)
# Out:
#      Rank            City           State  Population  Metro_Population  \
# 0       1          Mumbai     Maharashtra    12442373          18414288
# 1       2           Delhi           Delhi    11034555          16314838
# 2       3       Bangalore       Karnataka     8443675           8499399
# 3       4       Hyderabad  Andhra Pradesh     6731790           7749334
# 4       5       Ahmedabad         Gujarat     5577940           6352254
# ..    ...             ...             ...         ...               ...
# 487   488      Hinganghat     Maharashtra      101805            101805
# 488   489       Sujangarh       Rajasthan      101523            101523
# 489   490      Bhadreswar     West Bengal      101477            101477
# 490   491  Chilakaluripet  Andhra Pradesh      101398            101398
# 491   492         Kasganj   Uttar Pradesh      101277            101277
#
#      Sexratio  Literacy
# 0         853     89.73
# 1         876     87.59
# 2         923     88.71
# 3         955     83.26
# 4         898     88.29
# ..        ...       ...
# 487       936     93.25
# 488       956     73.33
# 489       903     86.51
# 490      1020     71.54
# 491       891     77.36
#
# [492 rows x 7 columns]

# %%
df.tail()
# Out:
#      Rank        City           State  Population  Metro_Population  Sexratio  \
# 493   494     Gangtok          Sikkim      100286            100286       912
# 494   495       Datia  Madhya Pradesh      100284            100284       900
# 495   496       Nagda  Madhya Pradesh      100039            100039       947
# 496   497    Banswara       Rajasthan       99969            101177       960
# 497   498  Kapurthala          Punjab       98916             98916       839
#
#      Literacy
# 493     89.33
# 494     80.56
# 495     80.71
# 496     85.72
# 497     85.08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              498 non-null    int64
#  1   City              498 non-null    object
#  2   State             498 non-null    object
#  3   Population        498 non-null    int64
#  4   Metro_Population  498 non-null    int64
#  5   Sexratio          498 non-null    int64
#  6   Literacy          498 non-null    float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 27.4+ KB

# %%
df2 = pd.read_excel('data/Report card.xlsx')

# %%
df2
# Out:
#       Student  Hindi  English  Maths  Science
# 0      Anchal     34       56      6        7
# 1   Divyanshi     34       45     34       34
# 2       Priya     56       56     34       34
# 3     Anshika     67        7     34       34
# 4      Nikita     87       67      4       43
# 5       Gopal     87       67     43       34
# 6       Ankit     89       67     34       43
# 7  Shubhankar     67       54     34       87

# %%
df2.columns
# Out:
# Index(['Student', 'Hindi', 'English', 'Maths', 'Science'], dtype='object')

# %%
df2['Totoal'] =df2['English'] + df2['Hindi'] + df2['Maths'] + df2['Science']

# %%
df2['Totoal'].plot(kind='bar', figsize=(15,5))
# Out:
# <AxesSubplot: >

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  8 non-null      object
#  1   Hindi    8 non-null      int64
#  2   English  8 non-null      int64
#  3   Maths    8 non-null      int64
#  4   Science  8 non-null      int64
#  5   Totoal   8 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 512.0+ bytes

# %%
df2.describe()
# Out:
#           Hindi    English      Maths    Science      Totoal
# count   8.00000   8.000000   8.000000   8.000000    8.000000
# mean   65.12500  52.375000  27.875000  39.500000  184.875000
# std    22.53529  19.942328  14.466093  22.226111   50.662574
# min    34.00000   7.000000   4.000000   7.000000  103.000000
# 25%    50.50000  51.750000  27.000000  34.000000  145.750000
# 50%    67.00000  56.000000  34.000000  34.000000  190.500000
# 75%    87.00000  67.000000  34.000000  43.000000  231.500000
# max    89.00000  67.000000  43.000000  87.000000  242.000000

# %%
df.describe()
# Out:
#              Rank    Population  Metro_Population     Sexratio    Literacy
# count  498.000000  4.980000e+02      4.980000e+02   498.000000  498.000000
# mean   249.500000  4.498030e+05      5.556033e+05   932.903614   84.261004
# std    143.904482  1.029319e+06      1.501008e+06    55.392315    6.306394
# min      1.000000  9.891600e+04      9.891600e+04   709.000000   48.280000
# 25%    125.250000  1.256420e+05      1.384625e+05   894.250000   80.945000
# 50%    249.500000  1.841050e+05      2.048060e+05   925.000000   85.180000
# 75%    373.750000  3.495960e+05      4.103862e+05   975.500000   88.612500
# max    498.000000  1.244237e+07      1.841429e+07  1093.000000   98.360000

# %%
df.describe(exclude=np.number)
# Out:
#               City          State
# count          498            498
# unique         497             30
# top     Aurangabad  Uttar Pradesh
# freq             2             64

# %%
df.describe(include='all')
# Out:
#               Rank        City          State    Population  Metro_Population  \
# count   498.000000         498            498  4.980000e+02      4.980000e+02
# unique         NaN         497             30           NaN               NaN
# top            NaN  Aurangabad  Uttar Pradesh           NaN               NaN
# freq           NaN           2             64           NaN               NaN
# mean    249.500000         NaN            NaN  4.498030e+05      5.556033e+05
# std     143.904482         NaN            NaN  1.029319e+06      1.501008e+06
# min       1.000000         NaN            NaN  9.891600e+04      9.891600e+04
# 25%     125.250000         NaN            NaN  1.256420e+05      1.384625e+05
# 50%     249.500000         NaN            NaN  1.841050e+05      2.048060e+05
# 75%     373.750000         NaN            NaN  3.495960e+05      4.103862e+05
# max     498.000000         NaN            NaN  1.244237e+07      1.841429e+07
#
#            Sexratio    Literacy
# count    498.000000  498.000000
# unique          NaN         NaN
# top             NaN         NaN
# freq            NaN         NaN
# mean     932.903614   84.261004
# std       55.392315    6.306394
# min      709.000000   48.280000
# 25%      894.250000   80.945000
# 50%      925.000000   85.180000
# 75%      975.500000   88.612500
# max     1093.000000   98.360000

# %%
df.isnull().sum()
# Out:
# Rank                0
# City                0
# State               0
# Population          0
# Metro_Population    0
# Sexratio            0
# Literacy            0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Student', 'Hindi', 'English', 'Maths', 'Science', 'Totoal'], dtype='object')

# %%
df.loc[100] # specific row, as a series
# Out:
# Rank                       101
# City                  Tiruppur
# State               Tamil Nadu
# Population              444352
# Metro_Population        962982
# Sexratio                   955
# Literacy                 87.81
# Name: 100, dtype: object

# %%
df.loc[100:120] # multiple rows, as a dataframe
# Out:
#      Rank               City           State  Population  Metro_Population  \
# 100   101           Tiruppur      Tamil Nadu      444352            962982
# 101   102         Davanagere       Karnataka      434971            434971
# 102   103          Kozhikode          Kerala      431560           2030519
# 103   104            Kurnool  Andhra Pradesh      430214            478124
# 104   105              Akola     Maharashtra      425817            425817
# 105   106    Rajpur Sonarpur     West Bengal      424368            424368
# 106   107       Bokaro Steel       Jharkhand      414820            563417
# 107   108            Bellary       Karnataka      410445            410445
# 108   109            Patiala          Punjab      406192            445196
# 109   110      South Dum Dum     West Bengal      403316            403316
# 110   111  Rajarhat Gopalpur     West Bengal      402844            402844
# 111   112          Bhagalpur           Bihar      400146            410210
# 112   113           Agartala         Tripura      400004            400004
# 113   114      Muzaffarnagar   Uttar Pradesh      392768            494792
# 114   115           Bhatpara     West Bengal      383762            383762
# 115   116              Latur     Maharashtra      382940            382940
# 116   117           Panihati     West Bengal      377347            377347
# 117   118              Dhule     Maharashtra      375559            375559
# 118   119             Rohtak         Haryana      374292            374292
# 119   120              Korba    Chhattisgarh      363390            365073
# 120   121           Bhilwara       Rajasthan      359483            359483
#
#      Sexratio  Literacy
# 100       955     87.81
# 101       979     84.90
# 102      1093     96.53
# 103      1013     77.06
# 104       959     91.91
# 105       970     90.14
# 106       889     83.47
# 107       991     78.38
# 108       884     85.78
# 109       995     92.09
# 110       976     89.69
# 111       880     79.26
# 112       999     94.45
# 113       899     79.80
# 114       887     84.74
# 115       937     84.22
# 116       992     91.92
# 117       941     87.86
# 118       888     85.70
# 119       925     83.38
# 120       922     82.20

# %%
df.loc[[51, 101, 201, 301]] # multiple rows in a list style
# Out:
#      Rank        City           State  Population  Metro_Population  Sexratio  \
# 51     52      Mysore       Karnataka      893062            983893       999
# 101   102  Davanagere       Karnataka      434971            434971       979
# 201   202     Murwara  Madhya Pradesh      221883            221883       924
# 301   302     Veraval         Gujarat      154636            184855       969
#
#      Literacy
# 51      87.67
# 101     84.90
# 201     85.91
# 301     76.87

# %%
cities = [51, 101, 201, 301, 401]
cols = ['City','Population']
df.loc[cities, cols] # multiple rows and columns specified
# Out:
#            City  Population
# 51       Mysore      893062
# 101  Davanagere      434971
# 201     Murwara      221883
# 301     Veraval      154636
# 401      Barshi      118722

# %%
df.loc[[51, 101, 201, 301, 401], ['City','Population']] # same as above
# Out:
#            City  Population
# 51       Mysore      893062
# 101  Davanagere      434971
# 201     Murwara      221883
# 301     Veraval      154636
# 401      Barshi      118722

# %%
df.loc[10:20]
# Out:
#     Rank                  City           State  Population  Metro_Population  \
# 10    11               Lucknow   Uttar Pradesh     2817105           2901474
# 11    12                Kanpur   Uttar Pradesh     2765348           2920067
# 12    13                Nagpur     Maharashtra     2405665           2497777
# 13    14                Indore  Madhya Pradesh     1964086           2167447
# 14    15                 Thane     Maharashtra     1841488           1841488
# 15    16                Bhopal  Madhya Pradesh     1798218           1883381
# 16    17         Visakhapatnam  Andhra Pradesh     1728128           1728128
# 17    18  Pimpri and Chinchwad     Maharashtra     1727692           1727692
# 18    19                 Patna           Bihar     1684222           2046652
# 19    20              Vadodara         Gujarat     1670806           1817191
# 20    21             Ghaziabad   Uttar Pradesh     1648643           2358525
#
#     Sexratio  Literacy
# 10       928     82.50
# 11       857     82.42
# 12       963     91.92
# 13       925     85.87
# 14       888     89.41
# 15       921     83.47
# 16       978     81.79
# 17       833     89.22
# 18       885     83.37
# 19       921     90.63
# 20       885     84.78

# %%
df2.iloc[:3]
# Out:
#      Student  Hindi  English  Maths  Science  Totoal  Total
# 0     Anchal     34       56      6        7     103    103
# 1  Divyanshi     34       45     34       34     147    147
# 2      Priya     56       56     34       34     180    180

# %%
df2['Student'] # single column as series
# Out:
# 0        Anchal
# 1     Divyanshi
# 2         Priya
# 3       Anshika
# 4        Nikita
# 5         Gopal
# 6         Ankit
# 7    Shubhankar
# Name: Student, dtype: object

# %%
df2['Hindi']
# Out:
# 0    34
# 1    34
# 2    56
# 3    67
# 4    87
# 5    87
# 6    89
# 7    67
# Name: Hindi, dtype: int64

# %%
df['Population']
# Out:
# 0      12442373
# 1      11034555
# 2       8443675
# 3       6731790
# 4       5577940
#          ...
# 493      100286
# 494      100284
# 495      100039
# 496       99969
# 497       98916
# Name: Population, Length: 498, dtype: int64

# %%
cols = ['State','Literacy','Population']
df[cols]
# Out:
#               State  Literacy  Population
# 0       Maharashtra     89.73    12442373
# 1             Delhi     87.59    11034555
# 2         Karnataka     88.71     8443675
# 3    Andhra Pradesh     83.26     6731790
# 4           Gujarat     88.29     5577940
# ..              ...       ...         ...
# 493          Sikkim     89.33      100286
# 494  Madhya Pradesh     80.56      100284
# 495  Madhya Pradesh     80.71      100039
# 496       Rajasthan     85.72       99969
# 497          Punjab     85.08       98916
#
# [498 rows x 3 columns]

# %%
df[['State','Literacy','Population']] # dataframe with multiple columns
# Out:
#               State  Literacy  Population
# 0       Maharashtra     89.73    12442373
# 1             Delhi     87.59    11034555
# 2         Karnataka     88.71     8443675
# 3    Andhra Pradesh     83.26     6731790
# 4           Gujarat     88.29     5577940
# ..              ...       ...         ...
# 493          Sikkim     89.33      100286
# 494  Madhya Pradesh     80.56      100284
# 495  Madhya Pradesh     80.71      100039
# 496       Rajasthan     85.72       99969
# 497          Punjab     85.08       98916
#
# [498 rows x 3 columns]
