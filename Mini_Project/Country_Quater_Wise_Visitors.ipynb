# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data/Country Quater Wise Visitors.csv")

# %%
df
# Out:
#       Country of Nationality  2014 1st quarter (Jan-March)  \
# 0                     Canada                          33.1
# 1   United States Of America                          25.7
# 2                  Argentina                          46.8
# 3                     Brazil                          31.0
# 4                     Mexico                          23.6
# ..                       ...                           ...
# 58                     Japan                          28.0
# 59       Korea (Republic Of                           32.1
# 60  Republic Of China Taiwan                          29.7
# 61                 Australia                          25.2
# 62               New Zealand                          25.5
#
#     2014 2nd quarter (Apr-June)  2014 3rd quarter (July-Sep)  \
# 0                          14.5                         15.7
# 1                          22.0                         20.6
# 2                          15.6                         13.9
# ...

# %%
df.columns.to_list()
# Out:
# ['Country of Nationality',
#  '2014 1st quarter (Jan-March)',
#  '2014 2nd quarter (Apr-June)',
#  '2014 3rd quarter (July-Sep)',
#  '2014 4th quarter (Oct-Dec))',
#  '2015 1st quarter (Jan-March) ',
#  '2015 2nd quarter (Apr-June)',
#  '2015 3rd quarter (July-Sep) ',
#  '2015 4th quarter (Oct-Dec) ',
#  '2016 1st quarter (Jan-March) ',
#  '2016 2nd quarter (Apr-June)',
#  '2016 3rd quarter (July-Sep) ',
#  '2016 4th quarter (Oct-Dec) ',
#  '2017 1st quarter (Jan-March) ',
#  '2017 2nd quarter (Apr-June)',
#  '2017 3rd quarter (July-Sep) ',
#  '2017 4th quarter (Oct-Dec) ',
#  '2018 1st quarter (Jan-March) ',
#  '2018 2nd quarter (Apr-June)',
#  '2018 3rd quarter (July-Sep) ',
#  '2018 4th quarter (Oct-Dec) ',
#  '2019 1st quarter (Jan-March) ',
#  '2019 2nd quarter (Apr-June)',
#  '2019 3rd quarter (July-Sep) ',
#  '2019 4th quarter (Oct-Dec) ',
#  '2020 1st quarter (Jan-March) ',
#  'Unnamed: 26',
#  '2020 2nd quarter (Apr-June)',
#  'Unnamed: 28',
# ...

# %%
df['Country of Nationality'].nunique()
# Out:
# 63

# %%
df.drop_duplicates(subset='Country of Nationality', inplace=True)

# %%
df['2014 1st quarter (Jan-March)'].value_counts()
# Out:
# 33.1    2
# 32.3    2
# 25.4    2
# 32.1    2
# 25.5    2
# 21.9    2
# 24.6    1
# 23.2    1
# 27.7    1
# 25.0    1
# 29.7    1
# 23.9    1
# 28.5    1
# 18.7    1
# 24.1    1
# 34.2    1
# 40.2    1
# 26.2    1
# 37.2    1
# 22.1    1
# 24.0    1
# 28.1    1
# 26.6    1
# 26.3    1
# 26.7    1
# 34.3    1
# 28.0    1
# 28.3    1
# 23.8    1
# 24.4    1
# 27.3    1
# 26.0    1
# 34.7    1
# 46.8    1
# 31.0    1
# 23.6    1
# 28.8    1
# 40.0    1
# 38.6    1
# 28.9    1
# 26.1    1
# 30.2    1
# 29.2    1
# 21.3    1
# 25.7    1
# 37.5    1
# 30.6    1
# 28.4    1
# 49.7    1
# 36.4    1
# 49.2    1
# 45.0    1
# 25.3    1
# 26.5    1
# 27.4    1
# 25.2    1
# Name: 2014 1st quarter (Jan-March), dtype: int64

# %%
df['2014 2nd quarter (Apr-June)'].value_counts()
# Out:
# 19.7    2
# 17.6    2
# 20.4    2
# 24.8    2
# 23.0    2
# 21.1    2
# 16.8    2
# 23.9    2
# 18.4    2
# 18.7    2
# 15.6    2
# 17.1    2
# 19.6    1
# 13.6    1
# 21.3    1
# 19.1    1
# 26.5    1
# 19.8    1
# 20.8    1
# 22.3    1
# 13.5    1
# 20.0    1
# 15.0    1
# 20.7    1
# 18.0    1
# 23.2    1
# 20.2    1
# 24.5    1
# 14.5    1
# 22.5    1
# 19.9    1
# 18.8    1
# 20.3    1
# 18.5    1
# 16.0    1
# 17.5    1
# 17.8    1
# 23.7    1
# 16.4    1
# 14.0    1
# 23.4    1
# 17.4    1
# 18.1    1
# 10.0    1
# 13.4    1
# 9.8     1
# 12.1    1
# 21.4    1
# 22.0    1
# 16.3    1
# Name: 2014 2nd quarter (Apr-June), dtype: int64

# %%
df['2014 3rd quarter (July-Sep)'].value_counts()
# Out:
# 22.4    4
# 19.9    2
# 26.1    2
# 23.0    2
# 21.6    2
# 22.7    2
# 22.6    2
# 18.9    2
# 20.5    2
# 20.3    1
# 27.1    1
# 27.0    1
# 32.8    1
# 33.5    1
# 22.1    1
# 38.1    1
# 23.7    1
# 15.7    1
# 27.9    1
# 29.4    1
# 21.4    1
# 27.8    1
# 26.4    1
# 8.1     1
# 12.5    1
# 25.1    1
# 18.4    1
# 21.2    1
# 22.0    1
# 17.4    1
# 27.3    1
# 13.9    1
# 18.7    1
# 26.5    1
# 16.2    1
# 13.5    1
# 23.6    1
# 22.8    1
# 17.5    1
# 35.1    1
# 12.4    1
# 20.1    1
# 22.9    1
# 9.7     1
# 17.0    1
# 5.1     1
# 11.0    1
# 26.2    1
# 20.7    1
# 20.6    1
# 18.3    1
# Name: 2014 3rd quarter (July-Sep), dtype: int64

# %%
df['2014 4th quarter (Oct-Dec))'].value_counts()
# Out:
# 30.3    3
# 28.6    3
# 22.4    2
# 30.8    2
# 22.8    2
# 30.4    2
# 29.3    2
# 29.6    2
# 31.5    2
# 30.6    2
# 22.1    1
# 29.9    1
# 19.6    1
# 25.5    1
# 34.4    1
# 25.3    1
# 27.9    1
# 36.7    1
# 23.8    1
# 27.4    1
# 44.0    1
# 26.5    1
# 34.7    1
# 41.4    1
# 29.5    1
# 27.2    1
# 26.2    1
# 39.3    1
# 31.4    1
# 28.1    1
# 25.0    1
# 25.8    1
# 23.7    1
# 27.8    1
# 27.5    1
# 30.0    1
# 29.8    1
# 29.4    1
# 34.1    1
# 26.0    1
# 36.1    1
# 32.1    1
# 33.2    1
# 35.9    1
# 31.9    1
# 27.1    1
# 34.2    1
# 31.7    1
# 37.3    1
# 39.9    1
# Name: 2014 4th quarter (Oct-Dec)), dtype: int64

# %%
df['2014 1st quarter (Jan-March)'].plot(kind='bar', figsize=(20, 5), title='Country wise graph')
# Out:
# <AxesSubplot: title={'center': 'Country wise graph'}>

# %%
df['2014 2nd quarter (Apr-June)'].plot(kind='bar', figsize=(20, 5), title='Country wise graph')
# Out:
# <AxesSubplot: title={'center': 'Country wise graph'}>

# %%
df['2014 3rd quarter (July-Sep)'].plot(kind='bar', figsize=(20, 5), title='Country wise graph')
# Out:
# <AxesSubplot: title={'center': 'Country wise graph'}>

# %%
df['2014 4th quarter (Oct-Dec))'].plot(kind='bar', figsize=(20, 5), title='Country wise graph')
# Out:
# <AxesSubplot: title={'center': 'Country wise graph'}>
