# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data/Top 10 State Visit.csv')

# %%
df
# Out:
#      year     top1_state   top1_ftv     top2_state   top2_ftv      top3_state  \
# 0  2014.0     Tamil Nadu  327555233  Uttar Pradesh  182820108       Karnataka
# 1  2015.0     Tamil Nadu  333459047  Uttar Pradesh  204888457  Andhra Pradesh
# 2  2016.0     Tamil Nadu  343812413  Uttar Pradesh  211707090  Andhra Pradesh
# 3  2017.0     Tamil Nadu  385909376  Uttar Pradesh  233977619       Karnataka
# 4  2018.0     Tamil Nadu  385909376  Uttar Pradesh  285079848       Karnataka
# 5  2019.0  Uttar Pradesh  535855162     Tamil Nadu  494865257  Andhra Pradesh
# 6  2020.0     Tamil Nadu  140651241  Uttar Pradesh   86122293       Karnataka
#
#     top3_ftv      top4_state   top4_ftv      top5_state  ...   top6_state  \
# 0  118283220     Maharashtra   94127124  Andhra Pradesh  ...    Telengana
# 1  121591054       Karnataka  119863942     Maharashtra  ...    Telengana
# 2  153163352  Madhya Pradesh  150490339       Karnataka  ...  Maharashtra
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      year     top1_state   top1_ftv     top2_state   top2_ftv      top3_state  \
# 0  2014.0     Tamil Nadu  327555233  Uttar Pradesh  182820108       Karnataka
# 1  2015.0     Tamil Nadu  333459047  Uttar Pradesh  204888457  Andhra Pradesh
# 2  2016.0     Tamil Nadu  343812413  Uttar Pradesh  211707090  Andhra Pradesh
# 3  2017.0     Tamil Nadu  385909376  Uttar Pradesh  233977619       Karnataka
# 4  2018.0     Tamil Nadu  385909376  Uttar Pradesh  285079848       Karnataka
# 5  2019.0  Uttar Pradesh  535855162     Tamil Nadu  494865257  Andhra Pradesh
# 6  2020.0     Tamil Nadu  140651241  Uttar Pradesh   86122293       Karnataka
#
#     top3_ftv      top4_state   top4_ftv      top5_state  ...   top6_state  \
# 0  118283220     Maharashtra   94127124  Andhra Pradesh  ...    Telengana
# 1  121591054       Karnataka  119863942     Maharashtra  ...    Telengana
# 2  153163352  Madhya Pradesh  150490339       Karnataka  ...  Maharashtra
# ...

# %%
df.columns.tolist()
# Out:
# ['year',
#  'top1_state',
#  'top1_ftv',
#  'top2_state',
#  'top2_ftv',
#  'top3_state',
#  'top3_ftv',
#  'top4_state',
#  'top4_ftv',
#  'top5_state',
#  'top5_ftv',
#  'top6_state',
#  'top6_ftv',
#  'top7_state',
#  'top7_ftv',
#  'top8_state',
#  'top8_ftv',
#  'top9_state',
#  'top9_ftv',
#  'top10_state',
#  'top10_ftv']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         7 non-null      float64
#  1   top1_state   7 non-null      object
#  2   top1_ftv     7 non-null      int64
#  3   top2_state   7 non-null      object
#  4   top2_ftv     7 non-null      int64
#  5   top3_state   7 non-null      object
#  6   top3_ftv     7 non-null      int64
#  7   top4_state   7 non-null      object
#  8   top4_ftv     7 non-null      int64
#  9   top5_state   7 non-null      object
#  10  top5_ftv     7 non-null      int64
#  11  top6_state   7 non-null      object
#  12  top6_ftv     7 non-null      int64
#  13  top7_state   7 non-null      object
#  14  top7_ftv     7 non-null      int64
#  15  top8_state   7 non-null      object
#  16  top8_ftv     7 non-null      int64
#  17  top9_state   7 non-null      object
#  18  top9_ftv     7 non-null      int64
# ...

# %%
df['year'].nunique()
# Out:
# 7

# %%
df.drop_duplicates(subset='year', inplace=True)

# %%
df['top1_state'].value_counts()
# Out:
# Tamil Nadu       6
# Uttar Pradesh    1
# Name: top1_state, dtype: int64

# %%
df['top2_state'].value_counts()
# Out:
# Uttar Pradesh    6
# Tamil Nadu       1
# Name: top2_state, dtype: int64

# %%
df['top3_state'].value_counts()
# Out:
# Karnataka         4
# Andhra Pradesh    3
# Name: top3_state, dtype: int64

# %%
df['top4_state'].value_counts()
# Out:
# Andhra Pradesh    3
# Karnataka         2
# Maharashtra       1
# Madhya Pradesh    1
# Name: top4_state, dtype: int64

# %%
df['top5_state'].value_counts()
# Out:
# Maharashtra       4
# Andhra Pradesh    1
# Karnataka         1
# Telengana         1
# Name: top5_state, dtype: int64

# %%
df['top6_state'].value_counts()
# Out:
# Telengana      4
# Maharashtra    2
# West Bengal    1
# Name: top6_state, dtype: int64

# %%
df['top7_state'].value_counts()
# Out:
# Madhya Pradesh    3
# West Bengal       3
# Telengana         1
# Name: top7_state, dtype: int64

# %%
df['top8_state'].value_counts()
# Out:
# West Bengal       3
# Madhya Pradesh    3
# Telengana         1
# Name: top8_state, dtype: int64

# %%
df['top9_state'].value_counts()
# Out:
# Gujarat      6
# Jharkhand    1
# Name: top9_state, dtype: int64

# %%
df['top10_state'].value_counts()
# Out:
# Rajasthan    6
# Punjab       1
# Name: top10_state, dtype: int64

# %%
df['top1_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='State wise graph')
# Out:
# <AxesSubplot: title={'center': 'State wise graph'}>

# %%
df['top2_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='State wise graph')
# Out:
# <AxesSubplot: title={'center': 'State wise graph'}>

# %%
df['top3_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='State wise graph')
# Out:
# <AxesSubplot: title={'center': 'State wise graph'}>

# %%
df['top4_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='State wise graph')
# Out:
# <AxesSubplot: title={'center': 'State wise graph'}>

# %%
df['top5_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='State wise graph')
# Out:
# <AxesSubplot: title={'center': 'State wise graph'}>

# %%
df['top6_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='State wise graph')
# Out:
# <AxesSubplot: title={'center': 'State wise graph'}>

# %%
df['top7_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='Graph')
# Out:
# <AxesSubplot: title={'center': 'Graph'}>

# %%
df['top8_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='State wise graph')
# Out:
# <AxesSubplot: title={'center': 'State wise graph'}>

# %%
df['top9_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='State wise graph')
# Out:
# <AxesSubplot: title={'center': 'State wise graph'}>

# %%
df['top10_state'].value_counts().plot(kind='bar', figsize=(20, 5), title='State wise graph')
# Out:
# <AxesSubplot: title={'center': 'State wise graph'}>
